# %%
print("Hello")
print("World")
# Out:
# Hello
# World

# %%
text = ["Hello", "World"]

for i in text:
  print(i)
# Out:
# Hello
# World

# %%
text = ["Hello", "World"]

i = 0
while i < len(text):
  print(text[i])
  i += 1
# Out:
# Hello
# World
