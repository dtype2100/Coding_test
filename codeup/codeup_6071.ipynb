# %%
while True: # 에러가 발생하지만, 제출 시 문제풀이 성공
    a=input()
    a=int(a)
    if a==0:
        break
    else:
        print(a)
# Out:
# 7 4 2 3 0 1 5 6 9 10 8
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-522fd4956e9d> in <module>()
#       1 while True:
#       2     a=input()
# ----> 3     a=int(a)
#       4     if a==0:
#       5         break
#
# ValueError: invalid literal for int() with base 10: '7 4 2 3 0 1 5 6 9 10 8'
