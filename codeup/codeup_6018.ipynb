# %%
a, b = input().split(':')
print(a, b, sep=':')
# Out:
# 3:16
# 3:16

# %%
a, b = input().split(':')
print(a, b, sep=':')
# Out:
# 3:16
# 3:16

# %%
a, b = input().split(':')
c = []
for i in a, b:
  print(a, b)
  c.append(a)
  c.append(b)
# Out:
# 3:16
# 3 16
# 3 16

# %%
type(c)
# Out:
# list

# %%
a, b = input().split(':')
d = []
for i in a, b:
  print(a, b, sep=':')
  d.append(a)
  d.append(b)
# Out:
# 3:16
# 3:16
# 3:16

# %%
d
# Out:
# ['3', '16', '3', '16']

# %%
c
# Out:
# ['3', '16', '3', '16']

# %%
type(c)
# Out:
# list

# %%
type(d)
# Out:
# list
