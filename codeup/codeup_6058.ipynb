# %%
a, b = map(int, input().split())
print(not bool(a or b))
# Out:
# 0 0
# True

# %%
a, b = input().split()
c= bool(int(a))
d= bool(int(b))

print( not (c or d) )

# %%
a, b = input().split()
c= bool(int(a))
d= bool(int(b))

print( c==False and d==False )
